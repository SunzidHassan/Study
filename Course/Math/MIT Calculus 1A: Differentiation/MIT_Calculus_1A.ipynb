# %% [markdown]
# ## 0. Limits
# ### 0.1 Limits
# **Right-hand limit**: $\lim_{x \to a^+}f(x)=R$
#
# **Left-hand limit**: $\lim_{x \to a^-}f(x)=L$
#
# - $L$ or $R$ may not exist.
# - $L$ may not be equal to $R$.
# - R may not be equal to $f(a)$
# - If $f(a)$ exists, R may not exist.
#
# - If $\lim_{x \to a^+}f(x)=\lim_{x \to a^-}f(x)$, then $\lim_{x \to a}f(x)$
#
# - If $\lim_{x \to a}f(x)=L$ and $\lim_{x \to a}g(x)=M$, then
#     - $\lim_{x \to a}[f(x)+g(x)]=L+M$
#     - $\lim_{x \to a}[f(x)-g(x)]=L-M$
#     - $\lim_{x \to a}[f(x).g(x)]=L.M$
#     - $\lim_{x \to a}{[f(x)\over g(x)]}={L\over M}$, if $M\neq 0$

# %%
import math
# Lim goes to +inf
def lim1(x):
    return round((abs(x)+math.sin(x))/x**2,3)

# Lim doesn't go to inf, but doesn't converge to a number
def lim2(x):
    return round(math.sin(13/x), 3)
    
x = [1, .5, .1, .01, .001, .0001]

for vals in x:
    print("lim1 values", lim1(vals))
print()
for i in range(10):
    print("lim2 values", lim2(10**-i))
# Out:
# lim1 values 1.841
# lim1 values 3.918
# lim1 values 19.983
# lim1 values 199.998
# lim1 values 2000.0
# lim1 values 20000.0
#
# lim2 values 0.42
# lim2 values -0.93
# lim2 values -0.581
# lim2 values 0.089
# lim2 values 0.781
# lim2 values 0.448
# lim2 values 0.998
# lim2 values -0.598
# lim2 values 0.122
# lim2 values 0.94

# %% [markdown]
# ### 0.2 Continuity
#
# **Continuous function:** $f$ is continuous at point $x=a$ if $$\lim_{x\to a}f(x)=f(a).$$
# - $f(a)$ exists
# - $\lim_{x\to a}f(x)$ exists
# - LHL and RHL are equal
# - $\lim_{x\to a}f(x)=f(a)$.
#
# For continuous functions, we can get $\lim_{x\to a}f(x)$ by calculating $f(a)$.
#
# Pictorially, there is a whole in graph if it's not continuous, and point if continuous.
#
# $f$ is right-continuous at $x=a$ if $\lim_{x\to a^+}f(x)=f(a).$
# $f$ is left-continuous at $x=a$ if $\lim_{x\to a^-}f(x)=f(a).$
#
# #### Types of discontinuities
#
# If LHL and RHL exist at a point $x=a$, but they are not equal, then $f$ has a **jump discontinuity** at $x=a$.
# ![Function with jump discontinuity](Images/images_u0lim2_jump.svg)
#
# If the overall $\lim_{x\to a}f(x)$ exist (i.e., LHL=RHL), but $\lim_{x\to a}f(x)\neq f(a)$, then $f$ has a **removable discontinuity** at $x=a$.
# ![Function with removable discontinuity](Images/images_u0lim2_removable.svg)
#
# Functions can be continuous for specific values of $x$ like continuous at $x=c$. If it's continuous for all values of $x$, it's called **continuous Everywhere** or just continuous.

# %%
# Some continuous functions
import matplotlib.pyplot as plt
import numpy as np
import math

def fun1(x):
    return np.full_like(x, 3)

def fun2(x):
    return x

def fun3(x):
    return abs(x)

def fun4(x):
    return np.sin(x)

x = np.linspace(-5, 5, 100)

y1 = fun1(x)
y2 = fun2(x)
y3 = fun3(x)
y4 = fun4(x)

plt.plot(x, y1, label="f(x)=3")
plt.plot(x, y2, label="f(x)=x")
plt.plot(x, y3, label="f(x)=|x|")
plt.plot(x, y4, label="f(x)=sin(x)")

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Limit laws and continuity
# If $f$, $g$ are continus at $x=a$, then
#
# $\lim_{x\to a}f(x)=f(a)$
#
# $\lim_{x\to a}g(x)=g(a)$,
#
# If,
# $h(a)=f(a).g(a)$,
#
# then,
# $\lim_{x\to a}h(x)=h(a)$
#
# If $f$, $g$ are continuous everywhere, then
# - $f.g$
# - $f+g$
# - $f-g$
# - $f\circ g$ are continuous everywhere. $f\circ g$ indicates $f(g)$ nested inside $f(x)$ (e.g., $f\circ g$: $sin(x^2+1)$).
# - $f/g$ is continuous where defined. $tanx={sinx\over cosx}$ is continuous when $cosx\neq 0$.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.linspace(-math.pi, math.pi, 100)

y = np.tan(x)

plt.plot(x, y, label="y=tan(x)")

plt.xlabel('x')
plt.ylabel('y')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 0.2.10 Catalog of continuous functions
# The following functions are continuous at all real numbers:
# - all polynomials
# - $\sqrt[3]{x}$
# - $|x|$
# - $\cos{x}$ and $\sin{x}$
# - exponential functions $a^x$ with base $a>0$.
#
# The following functions are continuos (or right continuous) at the specified values of x.
# - $\sqrt{x}$, for $x\geq{0}$
# - $\tan{x}$, at all $x$ where it is defined
# - logarithmic functions $\log_{a}{x}$ with base $a>0$, for $x>0$.
#
# #### 0.2.11 Intermediate Value Theorem
# If $f$ is *continuous* on the interval $[a, b]$ and $M$ is between $f(a)$ and $f(b)$ - or is an intermediate value, then there is at least one point $c$ between $a$ and $b$ such that $f(c)=M$.
#
# A function $f$ if continuous on a closed interval $[a, b]$ if it is right-continuous at $a$, left-continuous at $b$, and continuous at all points between $a$ and $b$.
#
# Example application:
# We want to know if the function $x^4-x-1$ has roots (value of $x$ for which $x^4-x-1=0$). But we can't directly factorize 4-th degree polynomial. Since it's a polynomial, it's continuous everywhere. Using IVT with $M=0$, we can find if $x$ has at least one root.
#
# Now, for $x=1$, $x^4-x-1=-1$ and for $x=2$, $x^4-x-1=13$. So, $x^4-x-1=-1$ has at least one root between $x=1$ and $x=2$.

# %%
import math
def func1_2_1(x):
    return (x**0.5)-math.cos(x)

print(func1_2_1(0))
print(func1_2_1(9))

def func1_2_2(x):
    return (4*x**-3)-x-math.sin(math.pi*x)

print(func1_2_1(-1))
print(func1_2_1(1))
# Out:
# -1.0
# 3.911130261884677
# (-0.5403023058681397+1j)
# 0.45969769413186023

# %% [markdown]
# ### 0.3 Limits of quotients
# #### Division Limit Law
#
# $\lim_{x\to a}f(x)=L$ and $\lim_{x\to a}g(x)=M$
#
#
# 1. $M\neq 0$, then $\lim_{x\to a}{f(x)\over{g(x)}}={L\over M}$.
# 2. $M=0$ and $L\neq 0$, then $\lim_{x\to a}{f(x)\over{g(x)}}=DNE$.
# 3. $M=0$ and $L=0$, then $\lim_{x\to a}{f(x)\over{g(x)}}$ may or may not exist. More work is necessary to determine whether the last type of limit exists, and what it is if it does exit.
# .
#
# #### Using the Division limit law
# $$\lim_{x\to 1}{x^2+2x-3\over{x^2-3x+2}}=\lim_{x\to 1}{(x-1)(x+3)\over{(x-1)(x-2)}}=\lim_{x\to 1}{(x+3)\over{(x-2)}}=-4$$
#
# $$\lim_{x\to -1}{x+1\over{x+{1 \over{x}}+2}}=\lim_{x\to -1}{x^2+x\over{x^2+1+2x}}=\lim_{x\to -1}{x(x+1)\over{(x+1)^2}}=\lim_{x\to -1}{x\over{(x+1)}}=DNE$$
#
# #### Division limit questions
#
# 1. $$\lim_{x\to 0^+}{2{\cos x}+1\over{x^2+x}}=DNE$$
#
# 2. $$\lim_{x\to 2}{{{1\over x}+x^2}\over{x-3}}=\lim_{x\to 2}{{1+x^3}\over{x^2-3x}}=-4.5$$
#
# 3. $$\lim_{x\to 2}{{{12\over x}-3x}\over{2-3x+x^2}}=\lim_{x\to 2}{{12-3x^2}\over{x(2-3x+x^2)}}=\lim_{x\to 2}{{3(4-x^2)}\over{x(x^2-2x-x+2)}}=\lim_{x\to 2}{{3(2+x)(2-x)}\over{x[x(x-2)-1(x-2)]}}=\lim_{x\to 2}{{3(2+x)(2-x)}\over{x(x-2)(x-1)}}=\lim_{x\to 2}{{3(2+x)}\over{x(1-x)}}=-6$$
#
# 4. $$\lim_{x\to 3}{{2x^2-10x+12}\over{x^3-6x^2+9x}}=\lim_{x\to 3}{{2(x^2-5x+6)}\over{x(x^2-6x+9)}}=\lim_{x\to 3}{{2(x^2-3x-2x+6)}\over{(x-3)^2}}=\lim_{x\to 3}{{2[x(x-3)-2(x-3)]}\over{(x-3)^2}}=\lim_{x\to 3}{{2(x-2)}\over{(x-3)}}=DNE$$
#
#
# 5. $$\lim_{x\to 0}{{3x^3+x^2}\over{x^3+x^2+x}}=\lim_{x\to 0}{{x^2(3x+1)}\over{x(x^2+x+1)}}=\lim_{x\to 0}{{x(3x+1)}\over{x^2+x+1}}=0$$
#
# #### Infinite limits
# $\lim_{x\to 0^+}{1\over x}=+\infin$
#
# $\lim_{x\to 0^-}{1\over x}=-\infin$
#
# $\lim_{x\to 0}{1\over x}=DNE$
#
# $\lim_{x\to 0^+}{1\over x^2}=+\infin$
#
# $\lim_{x\to 0^-}{1\over x^2}=+\infin$
#
# $\lim_{x\to 0}{1\over x^2}=+\infin$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function and the range of x values approaching 0 from both sides
x_right = np.linspace(0.01, 1, 400)  # Start from 0.01 to avoid division by zero on the right
x_left = np.linspace(-1, -0.01, 400)  # End at -0.01 to avoid division by zero on the left

y_right = 1 / x_right
y_left = 1 / x_left

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x_right, y_right, label=r'$y = \frac{1}{x}$ (Right side)')
plt.plot(x_left, y_left, label=r'$y = \frac{1}{x}$ (Left side)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title(r'Plot of $y = \frac{1}{x}$ as $x$ approaches 0 from both sides')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-100, 100)
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function and the range of x values approaching 0 from both sides
x_right = np.linspace(0.01, 1, 400)  # Start from 0.01 to avoid division by zero on the right
x_left = np.linspace(-1, -0.01, 400)  # End at -0.01 to avoid division by zero on the left

y_right = 1 / (x_right ** 2)
y_left = 1 / (x_left ** 2)

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x_right, y_right, label=r'$y = \frac{1}{x^2}$ (Right side)')
plt.plot(x_left, y_left, label=r'$y = \frac{1}{x^2}$ (Left side)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title(r'Plot of $y = \frac{1}{x^2}$ as $x$ approaches 0 from both sides')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(0, 100)
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function and the range of x values approaching 0 from both sides
x_left = np.linspace(1, 1.99, 400)  # Start from 0.01 to avoid division by zero on the right
x_right = np.linspace(2.01, 3, 400)  # End at -0.01 to avoid division by zero on the left

y_right = (3*x_right) / (4 - x_right ** 2)
y_left = (3*x_left) / (4 - x_left ** 2)

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x_right, y_right, label=r'$y = \frac{3x}{4-x^2}$ (Right side)')
plt.plot(x_left, y_left, label=r'$y = \frac{3x}{4-x^2}$ (Left side)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title(r'Plot of $y = \frac{3x}{4-x^2}$ as $x$ approaches 2 from both sides')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-50, 50)
plt.legend()
plt.grid(True)
plt.show()

# %%
import math

def lim14(x):
    return (2*x-1)/(1 - math.cos(x))

lim14(0.1)
# lim14(0.01)
# Out:
# -160.13340002646603

# %% [markdown]
# ## 1. The Derivative
#
# ### Derivative
#
# ### Geometric interpretation of the drivative
#
#
# ### The derivative as a function
#
#
# ### Calculating derivatives
#
#
# ### Leibniz notation
#
#
# ### Second derivatives and higher
#
#
# ### Trigonometric functions: sine and cosine

# %% [markdown]
# ## 2. Differentiation

# %% [markdown]
# ## 3. Approximations

# %% [markdown]
# ## 4. Applications
