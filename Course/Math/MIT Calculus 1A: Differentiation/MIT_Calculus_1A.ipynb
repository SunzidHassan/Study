# %% [markdown]
# ## 1. Limits
# ### 1.1 Limits
# **Right-hand limit**: $\lim_{x \to a^+}f(x)=R$
#
# **Left-hand limit**: $\lim_{x \to a^-}f(x)=L$
#
# - $L$ or $R$ may not exist.
# - $L$ may not be equal to $R$.
# - R may not be equal to $f(a)$
# - If $f(a)$ exists, R may not exist.
#
# - If $\lim_{x \to a^+}f(x)=\lim_{x \to a^-}f(x)$, then $\lim_{x \to a}f(x)$
#
# - If $\lim_{x \to a}f(x)=L$ and $\lim_{x \to a}g(x)=M$, then
#     - $\lim_{x \to a}[f(x)+g(x)]=L+M$
#     - $\lim_{x \to a}[f(x)-g(x)]=L-M$
#     - $\lim_{x \to a}[f(x).g(x)]=L.M$
#     - $\lim_{x \to a}{[f(x)\over g(x)]}={L\over M}$, if $M\neq 0$

# %%
import math
# Lim goes to +inf
def lim1(x):
    return round((abs(x)+math.sin(x))/x**2,3)

# Lim doesn't go to inf, but doesn't converge to a number
def lim2(x):
    return round(math.sin(13/x), 3)
    
x = [1, .5, .1, .01, .001, .0001]

for vals in x:
    print("lim1 values", lim1(vals))
print()
for i in range(10):
    print("lim2 values", lim2(10**-i))
# Out:
# lim1 values 1.841
# lim1 values 3.918
# lim1 values 19.983
# lim1 values 199.998
# lim1 values 2000.0
# lim1 values 20000.0
#
# lim2 values 0.42
# lim2 values -0.93
# lim2 values -0.581
# lim2 values 0.089
# lim2 values 0.781
# lim2 values 0.448
# lim2 values 0.998
# lim2 values -0.598
# lim2 values 0.122
# lim2 values 0.94

# %% [markdown]
# ### 1.2 Continuity
#
# **Continuous function:** if $\lim{x\to a}f(x)=f(a)$.
# For continuous functions, we can get $\lim{x\to a}f(x)$ by calculating $f(a)$.
# - $f(a)$ exists
# - $\lim{x\to a}f(x) exists
# - LHL and RHL are equal
# - $\lim{x\to a}f(x)=f(a)$.
#
# if $\lim{x\to a^+}f(x)=f(a)$, it's right-continuous, and vice versa.
# Pictorially, there is a whole in graph if it's not continuous, and point if continuous.
#
# If LHL and RHL exist at a point $x=a$, but they are not equal, then $f$ has a **jump discontinuity** at $x=a$.
#
# If the overall $\lim{x\to a}f(x)$ exist (i.e., LHL=RHL), but $\lim{x\to a}f(x)\neq f(a)$, then $f$ has a **removable discontinuity** at $x=a$.
#
# Functions can be continuous for specific values of $x$. If it's continuous for all values of $x$, it's called **continuous Everywhere** or just continuous.

# %%
# Some continuous functions
import matplotlib.pyplot as plt
import numpy as np
import math

def fun1(x):
    return np.full_like(x, 3)

def fun2(x):
    return x

def fun3(x):
    return abs(x)

def fun4(x):
    return np.sin(x)

x = np.linspace(-5, 5, 100)

y1 = fun1(x)
y2 = fun2(x)
y3 = fun3(x)
y4 = fun4(x)

plt.plot(x, y1, label="f(x)=3")
plt.plot(x, y2, label="f(x)=x")
plt.plot(x, y3, label="f(x)=|x|")
plt.plot(x, y4, label="f(x)=sin(x)")

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# If $f$, $g$ are continus at $x=a$, then
#
# $\lim{x\to a}f(x)=f(a)$
#
# $\lim{x\to a}g(x)=g(a)$, and
#
# $h(a)=f(a).g(a)$, and
#
# $\lim{x\to a}h(x)=h(a)$
#
# If $f$, $g$ are continuous everywhere, $f.g$, $f+g$, $f-g$ are continuous everywhere.
#
# Any polynomial is a continuous function.
#
# $f/g$ is continuous where defined.
# $tanx={sinx\over cosx}$ is continuous when $cosx\neq 0$.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.linspace(-math.pi, math.pi, 100)

y = np.tan(x)

plt.plot(x, y, label="y=tan(x)")

plt.xlabel('x')
plt.ylabel('y')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 2. The Derivative

# %% [markdown]
# ## 3. Differentiation

# %% [markdown]
# ## 4. Approximations

# %% [markdown]
# ## 5. Applications
