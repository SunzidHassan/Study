# %% [markdown]
# ## Lecture 1
# Terms to know
# 1. Intercellular: between cells
# 2. Microbiome: community of microorganisms
# 3. Intracellular: inside cells
# 4. Homeostasis: maintenance of nearly constant conditions in the internal environment.
# 5. Plasma (blood): liquid part of blood.
# 6. Interstitial fluid: body fluid between blood vessels and cells.
# 7. CNS: Central Nervous System
# 8. Hormones: are transported in the extracellular fluid to all parts of body to help regulate cellular function.
# 9. Hemoglobin: combines with oxygen as blood passes through lungs.
# 10. mM - mmol/L; uM - micromol/L, nM - nanomol/L
# 11. Negative feedback: nature of most control systems in physiology. Change initiates events that restores equilibrium. E.g., CO2 concentration regulation.
# 12. Positive feedback: also known as vicious cycle - initiating stimulus causes more of the same e.g., blood loss over 2 litre and heart weakening vicious cycle. Blood clotting.
# 13. Vicious cycles
# 14. Ions: an atome or molecule with net electric charge due to loss or gain of electrone(s).
# 15. Functional proteins: enzymes - catalyze specific chemical reactions. E.g., reactions which split glucose to provide energy are catalyzed by a series of protein enzymes.
# 16. Intracellular organelles: highly organized physical structures. E.g., mitochondia.
# 17. Plasma membrane: cell membrane. Lipid bilayer - hydrophilic phospholipid and hydrophobic fatty acid.
# 18. Glycoproteins: cell membrane protines.
# 19. Glycolipids: cell membrane lipids.
# 20. Cytoplasm: intracellular fluid (cytosol) filled with minute and large dispersed particles and organelles.
# 21. Endoplasmic reticulum: tubular and flat vesicular structures
# 22. Ribosomes: mixture of RNA and protein attached to the outer surface of parts of ER (granular ER) that synthesize new protein molecules in the cell.
# 23. Golgi apparatus: closely related to SER. Prominent in secretory cells.
# 24. Lysosomes: breaking from golgi apparatus. Intracellular digestive system that allows cells to digest damaged cellular structure, food particles, unwanted matter.
# 25. Peroxisomes: similar to lysosomes, but constains oxidases instead of hydrolases. Can create hydrogen peroxide to oxidize poisonous substances.
# 26. Secretory vesicles: formed from ER or golgi apparatus, released from golgi, storage vesicles.
# 27. Mitochondria: powerhouse of cell. Contains own DNA.
# 28. ATP: Adenosine triphosphate - energy currency of the cell.
# 29. Nuclear pores: nuclear membrane is penetrated by several thousand nuclear pores. Allow small molecules to pass.
# 30. Nucleoli: one or more highly staining structures - accumulation of large amounts of RNA and proteins.
# 31. Endocytosis: system of cell ingestion by the cell.
# 32. Pinocytosis: only means by which large macromolecules such as most protein molecules can enter cells.
# 33. Phagocytosis: similar to pinocytosis, but involves large particles rather than molecules.
#
# ### Chapter 1
# Homeostasis **
#
# Molar gradients *: Page 20
#
# Negative feedback **: page 21
# Example: Breath more if CO2 is high - reverse the initial condition.
#
# Positive feedback - the initiating condition causes more to occur: heart failure after some blood loss.
#
# +/- feedback good and bad.

# %% [markdown]
# ### Chapter 2: cell and functions
#
# Ions, proteins, carbs, lipids.
#
# Membrans: page 31 *
#
# Compare nano, microns with cell size.
#
# Second messenger: cells don't get the primary signals (e.g., light, chemicals), they sense by second messenger.
#
# Cytoplasm
#
# Granulated ER: Ribosomes are made of RNA and protein that makes proteins.
# Smooth ER makes lipids.
#
# Golgi: secretion
#
# Enzymes can build or destroy.
#
# Hydrogen peroxide kills outer
#
# Mitochondria. Power house. The foldings are to increase surface area.
#
# Filament and tubular: page 46
#
# Nucleus: page 47
# Nucleus has its own membrane - nuclear envolope. ER is continuous with membrane.
#
# Nucleoli page 48: clumps in nucleus.
#
# Scales page 49 ***: volume of cell can be a 1000 times in diameter and a billion times than that of a virus.
#
#
#
# Proteins are more like molecules than particles.
#
# Antibodies marks pathogens.
#
# Autolysis page 55: damange cells during exercise, that gets stronger. Also get rid of damanged cells.

# %% [markdown]
# ## Lecture 2
# Terms to know:
# 1. Oxidative reactions: electrone transfer reaction. E.g., nutrient to energy release reactions (to ATP) in mitochondria.
# 2. ADP: Adenosine diphasphate.
# 3. Cilia: Ciliary movement is a whiplike motion of cilia on the surfaces of cells. E.g., surfaces of respiratory airways.
# 4. Deoxyribose: sugar
# 5. Hydrogen bonds: weak chemical bond
# 6. Genetic code: the code that controls the formation of proteins in the cell.
# 7. Triplet codons: genetic code consists of successive triplets of bases - code word that results in an amino acid, sequence of which make up the final protein.
# 8. Transcription: the process of transferring DNA code in nucleus to an RNA code in cytoplasm.
# 9. Ribose: in RNA instead of deoxyribose in DNA.
# 10. RNA polymerase: enzyme that helps formation of RNA.
# 11. Promoter: DNA strand immediately ahead of the initial gene is a sequence of nucleotides called promoter. RNA polymerase has an appropriate complementary structure that recognizes this and becomes attached to it. This is the intial step of RNA formation.
# 12. Covalent bond: stronger chemical bond
# 13. Chain terminating sequence: method of DNA sequencing.
# 14. mRNA: messenger RNA. In the ribosome, each specific tRNA recognizes a particular codon on the messenger RNA. Thus tRNA delivers appropriate amino acid to the appropriate place in the chain of the newly forming protein molecule.
# 15. tRNA: transfer RNA - transfers amino acid molecules to protein molecules in ribosomes as protein is synthesized.
# 16. Ribosomal RNA: about 60% of ribosome, rest is proteins - both helps protein formation. Forms and collects in nucleolus.
# 17. Start signal: a codon that represents signal 'start'.
# 18. Anticodon: the specific triplet code in the tRNA that allows it to recognize a specific codon is anticodon. Located in the middle of tRNA. During formation of protein molecule, anticodon bases combine loosely by hydrogen bonding with codon bases of mRNA.
# 19. Translation: when mRNA travels through the ribosome, protein molecule is formed with translation.
# 20. Polyribosomes: clusters of ribosome attached to single mRNA that forms protein molecules at several ribosomes at the same time.
# 21. Polypeptide: protein
# 22. Peptide linkage: amino acid in protein chain are linked via a peptide linkage.
# 23. Operon: Synthesis of a cellular biochemical product usually requires a series of reactions, and each of these reactions is catalyzed by a special protein enzyme. Formation of all the enzymes needed for the synthesic process often is controlled by a sequence of genes located one after another on the same chromosomal DNA strand. This area of the DNA is called an operon, and the genes responsible for forming the respective enzymes are called structural genes.
# 24. Repressor protein: a band of nucleotides lying in the middle of the promoter called repressor. A regulatory protein can bind here and prevent attachment of RNA polymerase to the promoter - blocking transcription of the genes of this operon.
# 25. DNA polymerase: the principle enzymes for replicating DNA are DNA polymerase, comparable to RNA polymerase. It attaches to and moves along the DNA template strand while another enzyme, DNA ligase, causes bonding of successive DNA nucleotides one to another, using high energy phosphate bonds.
# 26. Ligase
# 27. DNA proofreading: during the hour between DNA replication and the beginning of mitosis, there is a period of active repaid and proofreading of the DNA strands. Whenever inappropriate DNA nucleotides have been matched up with the nucleotides of the original template strand, special enzymes cut out the defective areas and replace these with appropriate complementary nucleotides using same DNA polymerase and ligase used in replication.
# 28. Mutation: despite proofreading, if a mistake is made, it is called mutation - leading to abnormal protein formation, abnormal cellular function, even cell death.
# 29. Human genome: there are 25k+ genes in the human genome, each represented by two seperate sets of chromosomes with almost identical genes.
# 30. Histones: in addition to DNA, there are large amount of protein composed of small electropositively charge histone molecules in chromosomes. Small segments of DNA are coiled sequentially with histone cores. When DNA is packaged in histones, they can't function as a template for either RNA formation or replication of new DNA.
# 31. Contact inhibition: cells stop growing when they run out of space for growth.
# 32. Cell differentiation: change of physical and functional properties of cells as they proliferate in the embryo for form different bodily structures and organs. Proliferation and differentiation can't happen at the same time.
# 33. Apoptosis: when cells are no longer needed or become a threat to the organism, they undergo a suicidal programmed cell death or apoptosis.
# Cell necrosis: injury death of cell, causes inflammation.
# 34. Caspases: apoptosis is initiated by activation of a family of proteases called caspases.
# 35. Oncogenes: cancer is caused by abnormal activation of oncogenes that control cell growth and mitosis.
# 36. Carcinogens: chemical substances that increases probability of cancer.
# 37. Angiogenic factors: some cancers produce angiogenic factors that cause new blood vessels to grow into the cancer - thus supplying more nutrients.
#
# Word of the day: mage
#
#
#
# ### Chapter 2: Continued:
# Energy extraction page 2-4: glucose > ATP is mostly oxidative reaction.
#
# How is ATP used page 5-6: moving against gradient, , , ameboid motion.
#
# Ameboid locomotion - chemotaxis page 7:
#
# Cilia and ciliary movement page 8: fast push reset slow.
#
#
# ### Chapter 3: genetic control of peotein
# Page 9: Gnene > RNA > protein formation > cell structure and enzymes > cell function
#
# DNA page 11: backbone - phosphoric acid, deoxyribose. 4 bases - 2 purines (adenine, purines) and 2 pyrimidines (guanine, cytosine). Bonding AT/TA and CG/GC.
#
# All in middle...
#
# Amino acid 16:
#
# Page 17-20 ** - DNA > RNA: transcription
#
# Page 21: 3 types of RNAs
#
# 20 natural amino acids in human.
#
# Fix: Messenger RNA brings message from DNA, tRNA takes the message and takes it to Ribosomal RNA, Ribosome brings it all together to make proteins.
#
# Page 24: Fidelity of translation
#
# 26 - translation:
#
# 27 - polyribosomes:
#
# 29 - : genertic and enzyme regulation
#
# 30-31 - : promoter is always there, but repressor turns it off to stop transcription. Promoter activates the operon.
#
# 32 - negative feedback of operon:
#
# 33 - control with enzymes: Enzymes are often PH sensitive.
#
# ...
#
# 37 - : mutations are usually not good.
#
# Phosphate is acid - gives H+ and becomes negatively charged. DNA is an acid, is negatively charged, gets wrapped by positively charged proteins.
#
# 39 - cell growth:
#
# 41 : A cell can't proliferate and differentiate at the same time.
#
# 43 - necrosis: unplanned death of cell - causes inflammation.
#
# 45 : chemo kills cancer cells with necrosis. But there are ways to induce apos?
#
# Cencer**
#
# 46-47* - cancer: loss or inactivation of antioncogenes can allow oncogenes.

# %% [markdown]
# ## Lecture 3:
#
# 1-3 Coupled reaction:
#
# 4 Free energy:
#
# 5 ADP > nutrient > ATP > utilization
# ATP is labile: can't be stored efficiently.
#
# 6 Role of glucose: final products after digestion are 80% glucose, fructose and galactose.
#
# 7 Transport of glucose through cell membrane: they're too big - uses facilitated diffusion.
#
# 8 protein carrier molecules bind with glucose
#
# 10 insuline: increases rate of glucose transport in cell (10X). Rate of carb usage by most cells depends on insuline.
#
# 11 Kinase are enzymes that add phosphate. Phosphatase does the opposite. Glycogens is polymer and can store glucose. Glycogenesis is the process of making glycogen.
#
# 12 Glycogenolysis: (lysis is breaking) breaking one glucose at a time from glycogen.
#
# 13 fight/flight
#
# 14 small packet energy release. 38 moles fo ATP for each molecule of glucose.
#
# 15 Glycolysis: 3 carbons in
#
# 16 Acetyl coenzyme A. Citric acid cycle, mitochondria.
#
# 17 2 things comes at top, Oxaloacetic acid comes at bottom. If Acetyl Coen is available, it can repeat. Mitochondia use h2 and ener
#
# 18 NAD+ can form NADH which carries Hydrogen. CO2 is excreted.
#
# 19 Large quantities of ATP with oxiadtion of h2. Chemiosmodic? reaction
#
# 20 Citric acid cycle provides hydrogen, mitochrondia use
#
# 21 terms: oxidation, reduction - release or receive electrons. Cytochromes involves in
#
# 22 electron transport chain like hydroelectric dams:
#
# 23 we're formign distribution of charge and channelling them to form ATPs. Electrong transport chain is used
#
# 24 charged and concentration distribution: h ion flows from . The created ATP stays within the cell. Cell will use ATP and create ADP, which'll go inside mitochrondia to be ATP again.
#
# 25
#
# 26 summary of ATP formation duing glucose breakdown: max 38 ATP from each glucose molecule. 6 carbon glucose > 3 carbon pyruvic acid, Astocoy? carbon number - why they are important.
#
# 27 - negative and positive loop. - too much citraic acid -
#
# 28 glycolysis doesn't need oxygen. it's wasteful, forms lactic acid
# The citric acid cycle and mitochondria function needs oxygen. Without it pyruvic acid builds up > turns into lactic acid. It is utilized later, as the enzyme LDH is reversible once o2 is present. So if pyruvic acid diminishes, LDH creates more of it with o2.
#
# 29
#
# 30 building and storing fat from excess carb
#
# 31 Glucose conversion to glycogen or fat: gluconeogenesis. We can make glucose in our body from amino acid and fat.
#
# 32 The main job of amino acid is to create enzyme or structural protein. But diminished carbs can signal amino acids to create glucose. Cortisol, blood glucose level controls gluconeogenesis.
#
# 33 types of lipids
#
# 34 Triglycerides (lipid): energy
#
# 35
#
# 36 Lipid transport in body fluids:
#
# 37 removal of chylomicrons from blood: lipase enzyme works on lipids.
#
# 38 ... free fatty acids can move through blood. Fatty acid name. It's ionized.
#
# 39 Lipoproteins: LDL, HDL are important. Low HDL and high LDL is bad, both low is good, more HDL is good.
#
# 40
#
# 41 Saturation and double bond
#
# 42 Dynamic lipid
#
# 43 Liver lipids
#
# 44 unsaturated is less hydrogen and more double bonds
#
# 45
#
# Common metabolite is AcetolCo A

# %% [markdown]
# Home work 1
# 1. Intercellular means between cells.
# 2. Ribosomes are found in granular ER.
# 3. 50 micrometers.
# 4. C02.
# 5. Poorly
# 6. Lungs.
# 7. Concentration gradient.
# 8. 7.5-10 nanometers.
# 9.  10,000 fold.
# 10. Negative feedback loop.
# 11. Positive feedback loop. It's a good thing. It is bad in case of heart attacks.
# 12. Functional protein.
# 13. Decrease.
# 14. 1 molecule thick (wrong 2 layers).
# 15. Phosphate end is hydrophilic and fatty acid portion is hydrophobic.
# 16. In the outward-facing surface of the membrane?
# 17. CO2
# 18. Millimoles per liter.
# 19. RNA and proteins.
# 20. Smooth ER.
# 21. Peroxisomes constain oxidases rather than hydrolases of lysosomes.
# 22. Transcription.
# 23. Increases surface area.
# 24. 9 nanometers. Molecules up to 44,000 molecular weight can pass through.
# 25. Peptide linkage.
# 26. 5-10 micrometer.
# 27. Phagocytosis. (Exocytosis)
# 28. True.
# 29. Mitochondria.
# 30. 1. Phosphoric acid, 2. a sugar called deoxyribose, 3. four nitrogenous bases (two purines - adenine and guanine and two pyrimidines - cytosine and thymine).
# 31. Hydrogen bond.
# 32. The DNA strand immediately ahead of the initial gene is a sequence of nucleotides called the promoter. The RNA polymerase has an appropriate complementary structure that recognizes promoter and becomes attached to it.
# 33. Phosphate bond.
# 34. Messenger RNA.
# 35. Anticodon.
# 36. Translation.
# 37. a. decrease for Alzheimer's disease, b. increase for cancer.
# 38. Polyribosomes.
# 39. Promoter.
# 40. Regulatory protein called repressor.
# 41. Negative feedback effect. (Causing ...)
# 42. DNA ligase. or DNA polymerase
# 43. Histones, positive charge.
# 44. Neurons.
# 45. Stops cell growth. Decreases or inhibits.
# 46. tRNA.
# 47. Caspases.
# 48. Increase.
# 49. Carcinogens.
# 50. Angiogenic factors.

# %% [markdown]
# ## Lecture 4:
# Excitable tissues
#
# 2:
#
# 3: trnasport mechanism: facilitated diffusion takes energy. Active transport: against energy gradient.
#
# 4: diffusion: protein channels transport selectively
#
# 5: ... simple diffusion is linear. Facilitated diffusion has a limit
#
# 6: permeability of channels: voltage-gated - electro-chemical, ligand-gated: ligand binds to a receptor and it changes. Ligand can be other than protein (photons). Most channels are closed when not activated.
#
# 7: Permiability: gate can have negative charge (amino acid may be +/- or mostly nutral). K+ going out requires gate opening.
#
# 8: 3 factors of diffusion: concentration gradient, electrical potential, pressure - these are not mutually exclusive.
#
# 9: osmosis: water is dipolar - solves polar substances like NaCl.
#
# 10: aquaporins:
#
# 11: primary and secondary active transport: active transport: energy from ATP. Secondary: ionic concentration difference energy.
#
# 12: Ca-Na pump for
#
# 13:
#
# 14: active pump out or put it in ER. ATPase use ATP for work.
#
# 15: Secondary active transport/cotransport/counter transport:
#
# Na and glucose can happen and why, not where
#
# ### Chapter 5
#
# 16: Membrane potential
#
# Nernst potential: need to understand equation. Greater the potential, the greater the tendency to diffuse outside.
#
# Nernst potential - 3: Na is negative,
#
# Resting membrane potential - not needed: High concentration and far than equibrium will have greater effect. Close to equilibrium will have less impact.
#
# 20: K+ has higher gradient and greater impact. Pumps reestablish equilibrium. Resting membrane potential: -70.
#
# 21
#
# 22: Action potential:
#
# 23*: negative resting potential > stimulus > membrane is depolarized > Na+ channel activates > positive feedback: Na+ enters cell and makes it less negative > negative feedback starts: Na+ channel inactivaltes and K+ exits the cell > feedback loop stops: voltage gated channels close > resetting: >
#
# 24: Na+ and K+ gate activation
#
# 25: refractory period
#
# 26: properties of action potentials: all-or-none. 15mV positive change is threshold. Information is coded by frequency, not amplitude.
#
# 27: Rhythmicity: example - heart rate.
#
# 28: Propagation: theoritically electrical signals can travel both ways, but pre-senaptic to post-senaptic travel.
#
# 29: Myelinated vs: Myelin is a lipid rich insulator of nerve fibers. lets travel faster and provides insulation.
#
# * Schwan? cell mylinates? 1, oligodendrocite? cells mylinate? multiple cell.

# %% [markdown]
# ## Lecture 5: "Thinking in systems"
#
# 2.
#
# 3. System works, or breaks apart. We are a system. Systems can be self-repairing.
#
# 4. Positive and negative feedback loops for balancing.
#
# 5. Draw the diagram of negative feedback. Caffeine stimulates brain, increases blood flow, psychological boost.
#
# 6. Caffeine goes to bloodstream. Caffeine drop makes energy level drop.
#
# 7. Balancing feedback loop is goal and stability seeking. Is negative feedback loop.
#
# 8.
#
# 9. Axis: temperature and time. Coffea temprerature will come down to room temperature. Insulation for elengating temperature loss. The curve maybe smooth or occilating.
#
# 10. Balancing feedback loop: we balance blood-sugar with nutrition or internal insuline.
#
# 11. **Amplifying/reinforcing feedback loop** is positive loop.
#
# 12. Snow rolling.
#
# 13. Reinforcing loops whenever a system can reproduce itself. Seizures, stroke. Predatory/prey situation: competes against each other; ...
#
# 14. Exponential compound interest is reinforcing. COVID, pests, economy, weapons in arms race.
#
# 15. Reinforcing feedback loops are self-enhancing, leading to exponential +/- growth.
#
# 16. Economy, population growth.
#
# 17. Exercise: positive feedback thought problem
#
# 20. Predator-prey system - solves vs sheep: what influences the stock level of sheep. Starbuck's income. +/- factors.
#
# 21. Oscillation in a system - fishing fleet:
#
# 25. Oscilations: Exponential harvesting, capital and efficiency > reducing stock > reducing harvest and capital > stability or instability/crash.
#
# 26. Nonrenewable: finite stock available at once, higher extration will cause quicker exhaustion. Renewable: can support indefinite extraction if it doesn't exceed regeneration rate.
#
# 27.
#
# 28. Why do systems work: Resilience, self-organization, hierarchy
#
# 29. Resilience: the ability to recover from perturbation.
#
# 30. Self-organization: forming tissues in body.
#
# 31. Hierarchiy - bottom-up evolve: trees support in multiple dimension.

# %% [markdown]
# ## Lecture 6: Blood cell and immunity
#
# 2: Erythrocytes: transport hymoglobin > O2 carry, reversible **carbonic anhydrase** enzyme: work
#
# 3: water transports CO2 in the form of bicarbonate ion. Red blood cell act as acid-based buffer (is like negative feedback).
#
# 4: Biconcave, smaller than typical cell. Concave and deformable shape allows squeezing through narrow vessels.
#
# 5: Hematocrit: low oxygen at high altitude to compensate for low oxygen.
#
# 6: Erythropoiesis - genesis of blood cells. Glychoprotein EPO (Erythropoietin). Hypoxia - lowering oxygen.
#
# 7: Hemoglobin (Hb) formation: weak coordination bond of iron and oxygen for... Glycin is an amino acid that can be sued to build hemoglobin. Each has 16k molecular weight.
#
# 8: CO. Sickle cell anemia.
#
# 9: Destruction of Erythrocyte. Short life cycle as it doesn't have DNA for repair instruction.f
#
# 10: Macrophages
#
# 11: Anemia: no def, but know example.
#
# 12: Anemia lowers blood viscosity. Capillary dialates > more blood returns to blood > heart gets stronger and cardian output increases. Anemia increases bloodflow which is balancing.
#
# 13: Diapedesis: blood-brain barrier - neutrient or toxins doesn't go directly in blood. Chemotactic agents can be both attracting or repealing. Vess
#
# 14:
#
# 15: dead tissues rough cycle. Antibodies are flags that state stop and do somthing. Neutrophils, macrophase.
#
# 16:
#
# 17: Lymph is not water nor blood. Monocyte-phagocyte system: lymph node. Sinus is the central part. Input > process > output. Returns to the Venous blood.
#
# 18: Macrophages in lungs to protect from impurities, germs. As blood sqeezes through artery, capillary, tissues, returns through venous sinuses.
#
# 19: Basal dialation during inflammation, leakage of blood in tissue: edema.
#
# 20: Multiple line of defense: tissue macphophage first line, neutrophil second line.
#
# 21: Family of small molecules. TNF. Positive feedback system.
#
# 22:
#
# 23: Antibodies recognize antigens.
#
# 24: 2 types of lymphocytes: t generates tolerance against own antigens, b makes antibody.
#
# 25:
#
# 26:
#
# 27:
#
# 28: Antibody like Y with variable arms and a heavy region. These are large proteins. Affinity constant is measure of binding strength.
#
# 29: Focus on IgG: 75%, IgM has 10 binding sites.
#
# 30: Collection of 20 proteins, constant region binds to C1, amplification, leak out components
#
# 31: Lytic complex: making hole in membrane., histamines increase local blood flow that can cause .
#
# 32: Antibody recognition
#
# 33: Cell-mediated immunity: MHC is a protein in APC. Suppressor T cell as negative feedback in immune system.
#
# 34: Helper T (TH) cell: most numerous. There are many. Target cell of AIDS. Proliferation, differentiation positive feedback.
#
# 35: immune system attack cancer as they've wrong structure or protein.
#
# 36: suppressor T cell so that it doesn't attack implants.
#
# 37: COVID vaccine
#
# Glucose has 6 carbons, 180 weight.

# %% [markdown]
# ## Homework 2
# 1. in diffusion molecules move from high to low concentration with free energy. In active transport, molecules move from low to high concentration with energy input.
#
# 2. In simple diffusion, molecules  move through membrane opening or inter-molecular spaces without any interaction iwth protein channels. In facilitated diffusion, proteins act as carriers/pores to bind the substance and shuttle them through the membrane.
#
# 3. Rate limiting factor in facilitated diffusion is the maximum rate of transport at which the carrier can undergo changes back and forth between the binding and release states.
#
# 4. electrical concentration gradients for ions across membrane, properties of ion channels in the cell membrane, ion channel gate factors.
#
# 5. Three determining factors in ionic channel permiability are concentration gradient, electrial potential and pressure.
#
# 6. Binding of ligand with ligand-gated channel changes confimation that opens or closes the gate.
#
# 7. Na+=+55mV, K+=-90mV, Cl-=-65mV.
#
# 8. After the positive feedback loop of Na+, inactivation gate of voltage-gated Na+ channels closes and Na+ entry stops.
#
# 9. Myelin sheath thickness and axon diameter impacts propagation velocity.
#
# 10. Subsequent action potential can not be elicited before re-establishing Na+ and K+ ion concentration difference. Absolute refractory period is the time in which no action potential can be elicited regardless of stimulation strength.
#
# 11. Hyperpolarize; away from.
#
# 12. Oxidative phosphorylation is a cellular proceses that harnesses the reduction of oxygen to generate high-energy ATP.
#
# 13. 2 carbons.
#
# 14. Kinase catalyzes the transfer of phosphate groups from ATP to protein.
#
# 15. CO2 is the main waste product in Krebs cycle.  Blood carries CO2 to lungs which removes it by expiration.
#
# 16. Electron transport chain is in the inner membrane of the mitochrondia.
#
# 17. True.
#
# 18. Positive feedback.
#
# 19. Negative feedback.
#
# 20. NADPH can be used for the synthesis of fats from carbohydrates and synthesis of some other.
#
# 21. Three carbons.
#
# 22. Using serum albumin.
#
# 23. LDL has higher content of cholesterol.
#
# 24. Unsaturated fatty acids are usually more fluid.
#
# 25. True.
#
# 26. Negative
#
# 27. False!!
#
# 28. The target, goal or end point of a hot cup of coffee is the room temperature.
#
# 29. Positive feedback.
#
# 30. Exponential growth or runaway collapse.
#
# 31. True.
#
# 32. Lack of water may force sheeps to travel to open locations where wolves can catch them easily.
#
# 33. Typo.
#
# 34. False. Human hunting can help control overpopulation of the white-tailed deer.
#
# 35. False.
#
# 36. Flow rate limitation of O2 and glucose. (not Is not limited).

# %% [markdown]
# ## Lecture 7: Blood cell, immunity, blood clotting
# 1: Hemostasis: blood clotting
#
# 2:
#
# 3: Artery and vein differences: arteries work under pressure, more muscular - expand and contract more. Vein valves tend to bring the blood back to the heart. Movement helps blood bring back to heart.
#
# 4: Fibronectin*. Laminin: glycoprotein (hybrid of carb and protein). Collagen: family of proteins in tissue.
#
# 5: injury > vasal constriction
#
# 6: Coagulation > fibrin (promotes coagulation), lysis > coagulation
#
# 7: Know intrinsic (cutting of vessle, anemia) and extrinsic systems (blood senses phospholipid bilayer of membrane release by damanged cell). The two are not mutually exclusive.
#
# 8: Activation of coagulation: typical charge of cell is negative - . Extrinsic pathway (exetnal surface promotes clotting)
#
# 9: Know example of or recognize: Fibrinogen, Prothrombin, Calcium, Fibrin stabilizing factors. Cristmas factor (extra)
#
# 10: 1D monomer > polymer > 3D
#
# 11: Breakdown of polymer: with plasminogen activated by tPA (plasminogen activator) and kinase (enzymes that add phosphate or phosphorolation) that breaks polymer into monomers.
#
# 12: Positive feedback clotting (thrombin is positive feedback. Cloat and thrombus is similar) phospholipid is negative charge that helps, plasminogen (arrow with block is inhibition), ADP is lower energy state that signals cloting promotion ... is prevented with negative feedback. Heparin* (increases blood flow), antithrombin. Fibrinolysis: lysig the fibrine. Urokinase stimulates the process, ATP is higher energy states that signals OK.
#
# 13: Don't need to know granuals, but they exist. Von Willebrand factor - if negative charge, ADP, no heparin, rough surface, coagulation factor - platilets stops and releases other factors that help cloting.
#
# 14: Very short half-life. Packed platilets help blood clotting. Activated by ADP, thrombin (thrombus), fibrinogen
#
# 15: Platelet adhesion, aggregation, activation: right clotting in case of implants. Aggregation is mediated by Ca - positive ionic bridge that binds with negative. Cytokines recruit more platelets. Aspirin is wonder drug - impacts prostogland. Injury > blood flow up with prostogland > aspirin can inhibit it. Prostogland is related to pain, aspirin helps aleviate pain.
#
# 16: Smooth round to activate and change shape: vWF (von WIlli...) receptor
#
# 17: RGD is a small peptide that helps bind cells togther.
#
# 18: Drugs that inhibit platelet: prostaglandin, thromboxane systhesis. Aspirin inhibits cyclo-oxygenase. There are reversible (Ibuprofen) and irreversible (Aspirin) drugs. 2/3 names not needed. 4: RGD peptide analogs.
#
# 19: semipermeable barrier (leaky, unlike brain) for transfer between blood and surrounding. Thromboresistance is inhibiting clotting., important factors.
#
# 20:
#
# 21: Prostacyclin inhibits, degradation of ADP (debris) and inhibit clotting. Anticoagulant: inhibits thrombin, heparin Profibrinolytic plasmi activotor.
#
# 22: Normal endothelial cell: 3 in same direction: inhib platinlet by taking ADP, Nictric Oxyde increases blood flow, prostate gland (PG12). Profibrinolytic. Anticoagulant:
#
# 23: Disruption of endothelian consequence:
#
# 24: Endotoxin (promot inflammation; comes from bacteria), Cytokines (can increase blood flow and anema, other times increase caogulation), Thrombin
#
# 25: increase vWF, decrease . Anti-fibrinolytic: decrease tPA - increase controlled blood flow in brain after stroke. Platelet activating factors. Increase leukocyte adhesion.
#
# 26:
#
# 27: Antithrombotic agents: heparin. Antiplatelet agents:
#
# 28: Heparin: anti-coagulent. Can be reused by body. Negative charge. Sites where binds and thus inhibits thrombin.
#
# 29: Warfarin (Coumadin): related to Vitamin K. Competes with vitamin K Anticoagulant.
#
# 30: Coagulation cascade movie.

# %% [markdown]
# ## Lecture 8
# 1:
#
# 2: Concentration of the 3 checmical
#
# 3: Citric acid cycel: AcCo comes, but without OxA it piles. Kitosis sweat breath aceton.
#
# 4: more for lipid bilayer
#
# 5:
#
# 6: +/- feedback and balance.
#
# 7: *
#
# 8:
#
# 9: lipids create hormones
#
# 10: Atherosclerosis. Nitric oxide helps blood flow (- feedback for blood clotting)
#
# 11:
#
# 12: not good positive feedback
#
# 13: blockage of blood vessle
#
# 14:
#
# 15:
#
# 16:
#
# 17: HDL is good, HDL:LDL ratio is important.
#
# ### Chapter 69: protein metabolism
#
# 18:
#
# 19: amino acid molecular weight 100-200.
#
# 20: * albumin, globulin, fibrinogen protein in blood
#
# 21: essential proteins
#
# 22:
#
# 23:
#
# ### Chapter 74: Body temperature, regulation, fever
#
# 24:
#
# 25:
#
# 26:
#
# 27:
#
# 28: non-linear regions - when things are fine and when not. Vasal constricted - not losing heat.
#
# 29:
#
# 30:
#
# 31:
#
# 32: air convection
#
# 33:
#
# 42: aspirin masks fever

# %% [markdown]
# ## Lecture 9 - terms and concepts, not numbers
#
# 2: Alveolar pressure - no numbers: normal pressure, negative pressure till fill, positive pressure to excrete
#
# 3:
#
#
# 9: water and surface tension
#
# 10: surfactant: epithelial cells make surface
#
# 11: **surfactant decreases surface tension**. dipalmitoyl-PC has both phospho and lipid components
#
# 12:
#
# 13: assisted breathing for premature babies
#
# 14:
#
# 15: we don't breathe out 100% of the air. Tidal volume: inspired/expired with each breath. Inspiratory reserve volume: extra volume when full force. Expiratory reserve: max extra expired for force. Residual volume: remaining in lungs after force expiration
#
# 16: capacity
#
# 17:
#
# 19: action/resting: inhaler opens lungs.
#
# 20: histamine causes lung constriction
#
# 21: cilia movement
#
# 22:
#
# 23:
#
# ### Chapter 38 Pulmonary vessels
# 29: opposite of tissue (dump O2 where low): restrict alveoly where O2 is low.
#
# 31: edema (). 1. If blood pressure goes up due to heart failure, fluid increases.
#
# 32:
#
# ### Chapter 39
#
# 36: know relations
#
# 37:
#
# 39: relations for test
#
# 40: understand the terms of the formula
#
# 42: gas water has impact on partial pressure
#
# 43:
#
# 45: axis, curves, normal and dynamic state.
#
# 46: CO2 inversely proportionate to O2 and breathing.

# %% [markdown]
# ## HW3
#
# 1. Cells.
# 2. Increase.
# 3. 120 days.
# 4. True.
# 5. Viscosity decrease, blood return increase, heart rate increase.
# 6. True.
# 7. Increase, rough.
# 8. Decrease - False. Increase.
# 9. True.
# 10. Antigens.
# 11. Second.
# 12. 10nm.
# 13. True.
# 14. Increase local blood flow.
# 15. Lymphokines.
# 16. Collagen.
# 17. Increase.
# 18. True.
# 19. True.
# 20. tPA or tissue plasminogen activator is an enzyme that facilitates the breakdown of blood clots by converting plasminogen into plasmin.
# 21. Promote.
# 22. Inhibitor.
# 23. False.
# 24. Thrombin, prothrombin.
# 25. Attract.
# 26. Cyclo-oxygenase, thus inhibiting blood clotting.
# 27. Elongated.
# 28. Collagen, tPA, Von Willebrand's factor.
# 29. Increase.
# 30. False.
# 31. Increase.
# 32. Up.
# 33. Antifibrinolytic.
# 34. Thinning.
# 35. Decreased, thus decreasing blood clotting. False - decreased, thus increasing blood clotting.

# %% [markdown]
# ## HW4
