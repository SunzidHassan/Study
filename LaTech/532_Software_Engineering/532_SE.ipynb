# %% [markdown]
# ## 01. Why Software Engineering
#
# ### Learning Objectives
# - I can summarize 2-3 issues that can arise from adding more people to a soŌware project to meet a deadline
# - I can idenƟty 2-3 challenges soŌware engineering is designed to solve
# - I can give an example of a project that is well suited to use soŌware engineering principles

# %% [markdown]
# ## 02. Software Development Life Cycle
#
# ### Learning Objectives
# - I can recall the potenƟal stakeholders in a soŌware project
# - I can summarize the responsibiliƟes of each role in a soŌware project
# - I can match a set of responsibiliƟes to a role/stakeholder in a soŌware project
# - If asked for the responsibiliƟes of a specific role, I can tell the most important thing and maybe a few other things that flow out of that
# - I can recall the 6 to 8 stages of the SDLC, and map them to the beginning, middle, and end of a project.
# - I can summarize each of the stages of the SDLC.
# - Given a task or acƟvity, I can idenƟfy the appropriate SDLC stage where that acƟvity would most likely belong.
#
# ### Lecture
# First phase:
# Requirements
# Analysis: written by product owner that that can be understood by all. Understanding dependencies and doing prioritization. Checking of parties meant it.
# Prototyping and validation: success = maximizing feedback/minimizing cost. Engineers tend to build more and expend more. Prototypes shouldn't require coding. The goal is to keep/kill before you invest too much effort and grow emotions. Visual and interactive.
#
# Second: build and test should be seperate
# Build **: featuer driven development. When no more featuer needs to be added, alpha stage and start testing.
# Test (Bugs not usability):
#
#
# Deploy
# Document
# Maintain: KS - known shipable, new or unnoticed security threats, hardware/platform change

# %% [markdown]
# ## 03. Agile Development
#
# ### Learning Objectives
# - Identifying types of work
#     - I can describe incremental work with examples.
#     - I can describe iteraƟve work with examples.
#     - I recognize that work that is both incremental and iteraƟve is an appropriate candidate for agile management methodologies.
#     - I can cluster generalized descripƟons of work into one of four quadrants on incremental and iterative axes.
# - Understanding the tenets of the agile manifesto.
#     - I can recall the 4 guiding principles, or given a keyword reconstruct them.
#     - I can recognize descriptors and guiding philosophies for agile-appropriate work, and I can recommend acƟviƟes and pracƟces that align with those principles.
#     - I can recognize acƟviƟes that are and aren’t aligned with Agile management principles.
#
# ### Lecture
# Crunch: fix issues while developing new features
# Post-mortem: leadership member documents what needs to be stored as future reference.
#
# - Executive: sponsors the projejct, is responsible for the success/failure
# - Product owner: proxy of both customer and company, "accurate empathy". Communication between exec, marketer, dev, QA.
# - Marketer:
# - Technical lead: responsible for deciding approach, defines scope to management
# - Developer:
# - Customer: not necessarily the user
# - Project/product manager or Scrum master: fecilitate the process, tracks - making sure the train arrives and leaves on time.
# - QA: tries to break the software and finds bugs
#
#
# Product backlog:
#
#
# Waterfall: if every stage of development follows the previous one. Happens when the team, the need, the tools, etc. all stays same and risk is minimum. The requirements are known and won't change, the project has few unknows,
#
# Iterative development: steak example. The requirements are loose, many and changing unknowns, moving towards a target with each iteration.
#
# Incremental development: build baseball fields first, while it's in development build softball field, while they're in development build football field, and so on. Usually a large project, delivered components are fully functional, delivered over long period of time. Few unknowns and changing requirements.
#
# Iterative and incremental matrix:
#
#                                                  Iterative
# Iterative: high unknowns, experimental, improving | Agile: large scale, req are unknown; likely to change
# ------------------------------------------------------------------------------------------------------------ Incremental
# Waterfall: known and unchanging req, made once    | Delivered in phases; req less likely to change
#
#
# Agile:
#
# Agilemanifesto.org
# Individuals and interactions over processes and tools
# Working software over comprehensive documentation
# Customer collaboration over contract negotiation
# Responding to change over following a plan
#
# Face-to-face interaction
# Always have a workign build
# Embrace regular change
# Involve the customer

# %% [markdown]
# ## 04. Scrum
#
# ### Learning objectives:
# - I can explain what scrum is at a high level
# - Regarding user stories, I can:
#     - generate an appropriate/helpful user story
#     - recognize good and bad user stories
#     - identify components that are unhelpful, incomplete, or that need to be rewritten
#     - recall who is responsible for wriƟng user stories
# - Regarding release schedules, I can:
#     - divide the Ɵme into gates and sprints, with retrospecƟves and planning days (given a timeframe and alpha period)
#     - explain when it is appropriate to have shorter vs. longer sprints
# - Regarding sprints, I can:
#     - define and describe them
#     - determine the number of days spent working directly on new features (given x weeks)
# - Regarding retrospectives, I can explain:
#     - their purpose
#     - who attends them
#     - who leads them
#     - why it’s important to demo new features live
#     - who gives the feedback
# - Regarding sprint planning, I can:
#     - recall what I am responsible for producing before and during sprint planning
#     - recall what I am responsible for producing during sprint planning
#     - play planning poker
# - I know the three parts of standup, and can recognize common pitfalls
#
#
# ### Lecture
# Practicing agile development under management approach called 'Scrum'.
#
# (Scrum.org offers certificate.)
#
# Release planning: Product backlog (wish list) > Release backlog (commitment list)
#
# Release: timeline of start adn shipment goal
# Sprints:
# Release: lump sprints into gates, each targeting cohesive feature sets called epoch/epic
#
# Alpha: QA testing time when no new feature is added
#
# Crunch: building new feature during Alpha - poor management.
#
# Sprint: very focused time; bring one feature set; 2-3 days (high risk-freq check: new work, new team, new tool) to 2-3 weeks (low risk: known work, known team, known tool).
#
# Anatomy of sprint: 8 working day on 2 week > **Retrospective**: meeting with all stakeholder and product owner demos new features from perspective of user preferably in front of customer and the product owner adjusts release backlog > **Sprint planning**:
#
# Review retrospective:
#
# Pivot:
#
# Sprint planning:
#
# Features are written as user stories.
#
# Verify > done by product owner in repository.
#
# Input-output of sprint planning: Tasks (written by all team members), story points, estimates. Outcome: point estimate, hour estimate.
#
# Task writeup:
# User story: I have a batch of freshly backed chocolate chip cookies, the size of a human face, with an award winning receipy from the internet, they should be keto.
# Tasks: (with verb and noun phrase)
#     - recipe: find recipe using recipes.com
#     - ingredients: buy ingredients from Walmart Neighborhood
#     - prep: at my kitchen, lay out...
#     - implement recipe: mix ingredients
#     - ...
#     - bake for 25 mins on 325 degrees
#     - take out and let rest for 20 mins
# * at the end of the tasks being completed, the user story should be satisfied
#
#
# Story points: Time, number of systems, num of people, hard, arcane, tedious
#
# Agile planning poker: 1 is smallest, above 20 needs to be broken down. If everybody isn't within 1 step, discussion is needed.

# %% [markdown]
# ## 05. Requirements gathering
#
# ### Learning objectives
# - I can recall and explain the different types of requirements
# - I understand the importance of appropriate problem selec�on
# - I understand the difference between a tech demo and a use case
# - I can define the mindset of the product owner regarding the customer (accurate empathy)
# - I can suggest methodologies to gain accurate empathy
# - I can define gold pla�ng and scope creep, two threats that may arise during requirements gathering
#
# ### Lecture
# What is it?
# Who is it for?
#
# 1. Executive: sets constraints.
# 2. Post mortem for similar projects.
#
# All requirements and constraints are hypothesis.
#
# Product-market fit:
# Relation of value proposition and customer segment (from Business Model Canvas).
# Someone needs something, our product satisfies that need - AKA pain or gain.
# Human factors:
# 1. Needs (task analysis, user mapping/flow). Quantifying in terms of time to completion, satisfaction.
# 2. Values (pens model -- non-goal oriented behavior, **connectedness**, autonomy, mastery). Book: Symbols for sale (selling people's identity back to them). Documentary: Objectified.
# 3. Capabilities: extend or amplify
# 4. Limitations: complement (attention/memory)
#
# Accurate Empathy: the greatest trait a PO can have for the end-user.
#
# Cognitive baggage: when past experience interferes or enhances present experience. Accurate empathy requires understanding users cognitive baggage: you must meet ones expectation before exceeding or transforming them.
#
# Intuition: gut feeling based on past experience.
#
# To build intuitive software, a PO must have accurate knowledge of similar systems and the uer's training or past experience in order to have accurate empathy.
#
# Mapping: take something that user doesn't know and map it to something the user do know.
# Nesting: strategy to minitage information overload.
#
# What criteria do you consider when you apply a value judgement (good/bad) to a product, service or experience?
#
# Usability: information overload, trainign(higher/low)
# Brand fidelity and reputation (influence expectations, openness)
# Performance: speed (moment to moment latency in milliseconds), reliability, consistency
# Perceived efficiency (that could've been easier): number of screen or steps
#
# The cardinal rule of human factors (in which we design the work to match the worker): capacity > demand.
#
# Increase capacity (training, onboarding) or decrease (automated paths, limited functionality) - friendly for novice but often frustrating for expert users.
#
# Usability-functionality tradeoff: the tension between users and systems of varying capability, generally, is called the usability-functionality tradeoff.
#
# Objectives measures of performance:
# - Task analysis for goal-oriented interfaces:
#     - Task time to completion
#     - Error rate (errors of commission, errors of omission)
# - Systems usability survey: SUS (system usability scale) survey.
# - USE survey.
# - Cognitive walkthrough
# - interviews
# - ethnographic (value driven)

# %% [markdown]
# ## 06. Documentation
#
# ### Learning objectives:
# - I know who the audience is for documentation and how they might use it
# - I know the different types of documentation
# - I understand what good documentation looks like
# - I understand what bad looks like
#
# ### Lecture
# Documentation: **Be useful**
# Tool to use for documentation: https://readthedocs.org/dashboard/
#
# #### I know who the audience is for documentation and how they might use it
# - User: will need clear and easy to understand picture of main features and how to use them
# - Software development stakeholders: Product owner, fellow developers
# - Developer who'll further work on the project (e.g., for incremental update, someone who forked the repo in GitHub, etc.)
#
#
# #### I know the different types of documentation
#  - formal documentation -- wiki, website, .io, blog, Confluence, readme, google docs
#  - commenting code is a form of documentation
#  //assumes a one dimensional matrix eg n x 1
#  //results in a 1 x n matrix
#  public void transposeMatrix()
#  - changelogs/ checkins
#  - educational/ marketing content
#
#
# #### I understand what good documentation looks like
# Rubric for documentation
# - provide equal or greater value to readthedocs
# - Comprehensive.
# - navigation (table of contents or nav menu, headings, subheadings, entries (topics), subtopics)
# - entries with authorship, date
# - visual (dependencies, inheritance diagrams, models, math, data structures)
# - tables and charts (class/ object/ component responsibilities, etc.)
#
# Good examples
# https://docs.readthedocs.io/en/stable/
# https://docs.sunpy.org/en/stable/
# https://torchio.readthedocs.io/
# https://crest.readthedocs.io/en/stable/index.html
#
#
# #### I understand what bad looks like
# - Contains large pasted code sections without purpose driven flow or easy to understand explanation.
# - Without any proper organization or navigation.
# - Is not useful to the target user - e.g., does not provide tutorial for main features.
# - Lack of ownership.
# - Contains only text and code.
#
# Bad examples
# https://docs.google.com/document/d/19TQ-N0qqLsiRSJ4IyQoY9uKWKWb3p8tSxx0RW9oJJdE/edit?usp=sharing
# https://docs.google.com/document/d/1IG5i9dP3seYts-sNacO-UDdgq52-1pZxhhpbgJKGKiQ/edit?usp=sharing
# https://docs.google.com/document/d/12zuuQTlr3Mi79TAU4ZUBIMeGvW8IJlIo-14gCGMEePQ/edit?usp=sharing

# %% [markdown]
# ## 07. Tools
#
# ### Learning objectives
# - I can compare and contrast the characteristics of education and training
# - I understand how tools fit into education
# - I can recall the categories of types of tools that might show up for different needs in software development
# - I recognize some of the big names in tools and I know what those companies do or what their tools are used for
#
# ### Lecture
#
#
# #### I can compare and contrast the characteristics of education and training
# Education:
# - More on self-development
# - Focus on understanding generic and abstract ideas (e.g., understanding the math behind neural networks)
# - May not be useful at present
# - Education is usually more transferable
#
# Training:
# - Focuses on building specific skill for productivity
# - Focuses on tools (e.g., how to use PyTorch neural network)
# - Is applied in nature
# - Learned tool can be outdated/updated fast
#
#
# #### I understand how tools fit into education
#
#
# #### I can recall the categories of types of tools that might show up for different needs in software development
# #### I recognize some of the big names in tools and I know what those companies do or what their tools are used for
# SPRINT PLANNING AND MANAGEMENT
# - separate work
# - assign it/ delegate it
# - track progress (individual, pod, team, by feature)
# - track bottlenecks/ dependencies in work
# - visualization (scrum board, digital scrum boards)
# - spreadsheet or database-centrix systems for tracking hours/ points
# trello, sure
#
# VERSION CONTROL
# - manage changes
# - collaborate
# github, git, perforce
#
# DOCUMENTATION
# - navigable
# - helpful
# - clarity, robustness
# - cross-linking
# Confluence, readthedocs
#
# BUG REPORTING AND FIXING
# - QA to systematically report bugs
# - steps for recreation
# - assign it
# - test and verify it's fixed
# web helpdesk, jira, anything with a ticketing system
#
# CODE REVIEWS
# - adherence to coding standards
# - good decisions -- (SOLID), high cohesion, low coupling
# smartbear, Collaborator, generally these are plugins for version control
#
# TEAM COMMUNICATION
# - tribal knowledge
# outlook, discord, slack
#
# #### Approach to tools
# Likely to change
# HR recommendation -- one scripting language and one programming (compiled) language
# De-emphasize tools -- tool agnostic
# **Look for what's transferable
# **Look for the big ideas
# **Look at the commonalities between like tools

# %% [markdown]
# ## 08. Version Control
#
# ### Learning objectives:
# - I can explain at least two motivations for using version control
# - I understand what a repository is and its relationship to Git and GitHub
# - I can apply the basics of version control to GitHub to:
#     - Create a repository
#     - Add files
#     - Edit/Save files
#     - Create branches
#     - Make a pull request
#     - Resolve conflicts
#     - Merge branches
# - I can make a fork of a repository
# - I can apply the basics of version control to Git to:
#     - Clone a repository
#     - Stage files
#     - Commit
#     - Push
#
# ### Lecture
#
# #### I can explain at least two motivations for using version control
# - Better version control of a project
# - Allow better collaboration among team members
#
# #### I understand what a repository is and its relationship to Git and GitHub
# A repository is a storage where files, code, data, etc. can be stored.
# Git is a system of version control.
# GitHub is a platform that offers both version control and hosting services.
#
# #### I can apply the basics of version control to GitHub to:
# #### I can make a fork of a repository
#
#
# #### I can apply the basics of version control to Git to:
# Check git version: git -v
# - Clone a repository: git clone 'url'
# Check changes: git status
# pull: git pull
# - Stage files: git add *
# - Commit: git commit * -m "change description"
# - Push: git push

# %% [markdown]
# ## 09. Testing
# Testing types: Static and Dynamic testing
#
# Static: before runtime
# Dynamic: during runtime
#
# Static testing:
# - SOLID principles: high cohesion and low coupling.
#         Write code in a way so that change is easy and reduce coupling (change in one's behavior affects other).
#         SIngle responsibility: every line, function, class has a single conceptual responsiblity.
#         Functions should be open to extension, but not to modification.
#         Substitue principle: swaping lion with mammal should'nt break it.
#         Abstraction: Think through inheritance ahead of time.
# - Rubber ducking:
# - TDD: Test Driven Development - you write unit testing code first and then write the code. Combined unit testing codebase of a team that updates. If new code breaks a part of the unit test, it's known earlier.
#
# Behavior testing: throughout the build, test from end user perspective. Behavior Driven Development: test against user journey.
# The PO writes user story, a developer writes a scenario based on the user story. A Developer or build engineer automates via a BDD framework.

# %% [markdown]
# # Reading tasks
#
# ## 01. Adding more manpower to a late software project makes it later
# Software engineers are optimists in general, and they incorrectly assume that the project will go well. In the book “The Mind of the Maker”, creativity is divided in three stages – the idea, the implementation and the interaction. Since programming medium is tractable, a programmer assumes few difficulties in implementation. But the inconsistencies of the idea become clear during implementation of a large programming project.
# The assumption that more manpower will make the project finish faster doesn’t hold for projects that require communication among the workers. In tasks that can be partitioned but require communication among subtasks, the training and intercommunication can actually lengthen the schedule.
# Software managers often don’t negotiate project delivery timeline if the project schedule overruns. Sharing productivity, bug, estimation data can help customers accept extended delivery time.
# Because of optimism, programmers often assume the number of bugs to be smaller than it usually is. A good rule of thumb is to assign one-third of the time for planning (larger than normal but still insufficient), one-sixth for coding (as it’s easy to estimate), half of the time for debugging (larger than normal but practically needed). Since debugging part comes at the end, the secondary costs of project overrun is often significant.
# In case of project overrun in the first phase, it can firstly be assumed that the underestimation only applies for the first phase, and increase manpower to cover the overrun. This in turn will add training and communication requirement that can further overrun the project. Secondly, it can be assumed that the overrun represents actual time requirement, and the total project will require longer schedule. So, enough time can be taken so that further rescheduling is unnecessary. Lastly, the project can be trimmed in a planned way to reduce time requirements.
#
#
# ## 02. Scaling
# In many engineering disciplines, it is known that a small-scale experiment needs to be tested in a medium scale first before implementing it in a large-scale system. The same is applicable for programming projects as well, and software development management must plan for piloting and redeveloping.
# This is mandatory as change of user need is inevitable for software products or services. There needs to be a defined balance of the extent to which the developer needs to meet changing customer needs. The preparedness to meet this change needs to be incorporated in planning.
# Practices like modularization, subroutine, defining intermodular interfaces,  documentation, standard calling sequences and table-driven techniques, high-level language and self-documenting techniques, compile-time operations to incorporate standard declarations, quantization of change, numbering product versions with schedule and freeze date should be practiced.
# The planning process of the entire organization should facilitate change. Designers need to be responsible for the changes they make and document the design decisions. Sociological attention should be applied to make workforce interchangeable between development and management roles.
# Updating a software system often leads to new issues, which makes existing software system fragile with increasing updates. Thus, every software system must be developed from ground up after a threshold.
#
#
# ## 03. Productivity increase
# All software development involves essential tasks that include transforming concept into reality and accidental tasks that include representing the concepts in programming and machine language. A number of approaches can help with essential parts – exploiting what can be bought in mass market, using rapid prototyping to fix software requirements, growing features iteratively while they are in use, developing conceptual designers of rising generation. The essential difficulties of Software engineering include complexity. Software is the most complex entity for its size with complex non-linearities. Unlike other disciplines, software development has no objective conformity. It’s subject to constant change that increases entropy. The invisibility of software also makes agreement hard. In order to make improvements, refinement and rapid prototyping, incremental development, great designers is required.
#
#
# ## 04. Naming
# **Use intention-revealing names**
# Why it exists, what it does, how it's used. E.g.,
# int elapsedTimeInDays, int daysSinceCreation, etc.
#
# **Avoid disinformation**
# Avoiding reserved names, naming similar concepts similarly, avoiding using 'O' and 'l'.
#
# **Make meaningful distinctions**
# Avoiding noninformative number-series naming. Distinguishing name should indicate their difference.
#
# **Use pronounceable names**
# Humans are good at pronouncing words, and variable names should be pronounceable.
#
# **Use searchable names**
# Single-letter or numeric names are harder to search and thus should not be used for naming variables with wide scope.
#
# **Avoid encodings**
#
#
# **Hungarian notation**
# It is better to avoid type encoding since it's not mandatory with modern languages with complex options.
#
# **Member prefix**
# Names should not be too long that they need prefix.
